# %% [markdown]
# ## Learning Jupyter

# %%
import math
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
# print ten random numbers from the uniform distribution
print(np.random.uniform(0, 1, 10))
# Out:
# [0.32058398 0.210488   0.40911419 0.93474165 0.11161292 0.01397599
#  0.58663626 0.69880174 0.96626844 0.55747856]

# %%
# Create dummy data frame
df = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# Plot a pandas dataframe
df.plot()
# Out:
# <Axes: >
