# %% [markdown]
# ## Learning Jupyter

# %%
import math
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
print(np.random.rand())
# Out:
# 0.9942712502392792

# %%
# generate random data
data = np.random.randn(1000)

# create histogram
plt.hist(data, bins=30)

# show the plot
plt.show()

# %%
# Create dummy data frame
df = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# Plot a pandas dataframe
df.plot()

# Create an array of 1000 random numbers from a poisson distribution with lambda = 5
# Out:
# <Axes: >
