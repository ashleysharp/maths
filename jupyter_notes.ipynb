# %% [markdown]
# ## Learning Jupyter

# %%
import math
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
# print ten random numbers from the uniform distribution
print(np.random.uniform(0, 1, 10))
# Out:
# [0.4990061  0.38386449 0.9988278  0.43068873 0.3360565  0.99290794
#  0.62154158 0.304206   0.57411804 0.21168702]

# %%
# Create dummy data frame
df = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# Plot a pandas dataframe
df.plot()
# Out:
# <Axes: >
